# %%
import numpy as np
import pandas as pd

df = pd.read_csv("historical.csv")

from warehouse_organization_tool.utilities.warehouse_visualization import Warehouse_Visualization
from warehouse_organization_tool.utilities.warehouse import Warehouse

df
# Out:
#                item month  sales  inventory  orders  order size  turnover
# 0        lawn chair   Jan      5         50       0          20    0.1000
# 1        lawn chair   Feb      8         45       0          20    0.1778
# 2        lawn chair   Mar     12         37       0          20    0.3243
# 3        lawn chair   Apr     12         25       1          20    0.4800
# 4        lawn chair   May     23         33       1          20    0.6970
# ..              ...   ...    ...        ...     ...         ...       ...
# 79  flippy floppies   Aug     90        168       1         100    0.5357
# 80  flippy floppies   Sep     67        178       1         100    0.3764
# 81  flippy floppies   Oct     78        211       1         100    0.3697
# 82  flippy floppies   Nov     45        233       0         100    0.1931
# 83  flippy floppies   Dec     65        188       0         100    0.3457
#
# [84 rows x 7 columns]

# %%
  warehouse = Warehouse_Visualization(df=df)

# %%
warehouse.place_shelves()
warehouse.place_items()
# Out:
# placed waffle iron
# placed crossbows
# placed umbrellas
# placed lawn chair
# placed pool noodle
# placed flippy floppies
# placed cooler
# [[['' '']
#   ['' '']
#   ['' '']
#   ['' '']
#   ['pool noodle' '']
#   ['waffle iron' '']]
#
#  [['' '']
#   ['' '']
#   ['' '']
#   ['' '']
#   ['flippy floppies' '']
#   ['crossbows' '']]
#
#  [['' '']
#   ['' '']
#   ['' '']
#   ['' '']
#   ['cooler' '']
#   ['umbrellas' '']]
#
#  [['' '']
#   ['' '']
#   ['' '']
#   ['' '']
#   ['' '']
#   ['lawn chair' '']]]

# %%
warehouse.plot_grid()
# Out:
# [0, 120, 360, 480, 0, 120, 360, 480, 0, 120, 360, 480, 0, 120, 360, 480, 0, 120, 360, 480, 0, 120, 240, 360, 480]

# %%
warehouse2 = Warehouse_Visualization(length=100,width=100,height=20,df=df,lane_size=10)
warehouse2.place_shelves()
warehouse2.place_items()
# Out:
# placed waffle iron
# placed crossbows
# placed umbrellas
# placed lawn chair
# placed pool noodle
# placed flippy floppies
# placed cooler
# [[['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['waffle iron' '' '' '']]
#
#  [['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['crossbows' '' '' '']]
#
#  [['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['umbrellas' '' '' '']]
#
#  [['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['lawn chair' '' '' '']]
#
#  [['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['pool noodle' '' '' '']]
#
#  [['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['' '' '' '']
#   ['flippy floppies' '' '' '']]
#
#  [['' '' '' '']
# ...

# %%
warehouse2.plot_grid()
# Out:
# [0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 600, 720, 840, 960, 1080, 0, 120, 240, 360, 480, 600, 720, 840, 960, 1080]
